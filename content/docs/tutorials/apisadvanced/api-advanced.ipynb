# %% [markdown]
# # API Advanced (oDCM)
#
# *...*
#
# ---
#
# ## Learning Objectives
#
# Students will be able to:
# * Obtain authentication credentials and tokens, check for a valid connection, and renew tokens if expired.
# * Apply a multitude of filters, possibly from multiple endpoints, to narrow down search requests
# * Iterate over a variety of API search pages
# * Learn how to read API documentation independently
#
#
#
# ---
#
# ## Acknowledgements
# This course draws on a variety of online resources that can be retrieved from the [course website](https://odcm.hannesdatta.com/docs/about/).
#
# ---
#
# ## Contact
# For technical issues outside of scheduled classes, please check the [support section](https://odcm.hannesdatta.com/docs/course/support) on the course website.

# %% [markdown]
# ## 1. Authentication
#
# ### 1.1 Client Key & Client Secret
# **Importance**
# As you may remember, the `icanhazdadjoke` and `Reddit` APIs can be used right out of the box. They did not require you to create an account, login with your credentials, or provide any information associated with you. In this tutorial, we will request data from the Spotify Web API which takes a little bit more preparation.
#
# First, you need to [sign up](https://www.spotify.com/us/signup/) for a Spotify user account (Premium or free) if you do not already have one. Second, you log in to the [developer portal](https://developer.spotify.com/dashboard/applications) of Spotify and create a new app (you can give it any name and description you want). Third, you take note of the `Client ID` and `Client Secret` (we'll need those later on!).

# %% [markdown]
# <img src="images/Spotify_credentials.gif" align="left" width=70%/>

# %% [markdown]
# **Let's try it out!**
# Follow the steps above and assign the client key and secret you obtained to the variables below.

# %%
# your Spotify App credentials
client_id = "60f45fe73bef4bfbb7549dde2b02cab5"
client_secret = "6855d391f816439dbbeb54b997708efe"

# %% [markdown]
# Next, in the [API documentation](https://developer.spotify.com/documentation/general/guides/authorization-guide/) authorization guide, we find that the request requires a so-called base 64 encoded string that contains the client id and client secret that follows the format `Authorization: Basic *<base64 encoded client_id:client_secret>*`
#
# This is a more secure way to pass credentials to the API. We start out with an f-string that concatenates the `client_id` and `client_secret` variables. Thereafter, we encode this variable into base 64 using the `b64encode` function of the `base64` module.

# %%
import base64
client_creds = f"{client_id}:{client_secret}"
print(f"f-string: {client_creds}")

client_creds_encoded = base64.b64encode(client_creds.encode())
print(f"Base64 encoded: {client_creds_encoded}")
# Out:
# f-string: 60f45fe73bef4bfbb7549dde2b02cab5:6855d391f816439dbbeb54b997708efe
# Base64 encoded: b'NjBmNDVmZTczYmVmNGJmYmI3NTQ5ZGRlMmIwMmNhYjU6Njg1NWQzOTFmODE2NDM5ZGJiZWI1NGI5OTc3MDhlZmU='

# %% [markdown]
# You can think of it as codes and ciphers: you only send your base 64 encoded credentials to the API. So, if anyone would intervene and get their hands on the `client_creds_encoded` they still don't know your `client_id` and `client_secret`. On the other hand, the API is able to decode and thereby verify your authentication credentials.
#
# Finally, we turn the base64 encoded string into the requested format:

# %%
token_headers = {
    "Authorization": f"Basic {client_creds_encoded.decode()}"
}

token_header
# Out:
# {'Authorization': 'Basic NjBmNDVmZTczYmVmNGJmYmI3NTQ5ZGRlMmIwMmNhYjU6Njg1NWQzOTFmODE2NDM5ZGJiZWI1NGI5OTc3MDhlZmU='}

# %% [markdown]
# ### 1.2 Access Tokens
# **Importance**
# When your `client_id` and `client_secret` have been received, you will need to exchange it with an access token. That is, a temporary key associated with your account that expires in 60 minutes (3600 seconds). In practice, this means you need to regenerate your access code once in a while. To obtain an access token you make a POST request to the Spotify Accounts Service with the following endpoint: `https://accounts.spotify.com/api/token` and include two additional parameters `token_data` and `token_headers` (i.e., encoded client key and secret).

# %%
token_url = "https://accounts.spotify.com/api/token"

token_data = {
    "grant_type": "client_credentials"
}

r = requests.post(token_url, data=token_data, headers=token_headers)
token_response_data = r.json()

# %% [markdown]
# **Let's try it out!**
# Look up the `r.status_code` of your POST request. What does this tell you? Tip: have a look at the [response status codes](https://developer.spotify.com/documentation/web-api/)!

# %% [markdown]
# The `r.json()` method returns a dictionary that contains the `access_token` we're after:

# %%
token_response_data
# Out:
# {'access_token': 'BQCV9LB4hJxPbkRaMRvoEknqNaHF5AisWLlBLj1UVw_gK5Zl-GO0TO98wxivk-NoUtXWMATWPZOvKbDIGxU',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'scope': ''}

# %% [markdown]
# **Let's try it out!**
# Store the access token of the `token_response_data` object into the `access_token` variable below. What happens to the access token once you make another POST request?

# %%
access_token = ####

# %% [markdown]
# ### 1.3 Endpoints
# **Importance**
# Spotify collects large-scale data from multiple entities: artists, albums, playlists, tracks, not to mention all individual user-level data. These collections of data can be accessed through endpoints that prescribe the required parameters and the expected output. Each endpoint consists of a base URL and an endpoint. For example, the base URL for retrieving information about one or more tracks from the Spotify catalog is `https://spotify.com/v1/` and the endpoint `/tracks/{id}`. Taken together, an API request to `https://api.spotify.com/v1/tracks/2EqlS6tkEnglzr7tkKAAYD` returns track-level data (e.g., duration, popularity, artist) of `Come Together - Remastered 2009` by `The Beatles`.
#
# In a bit, we'll learn you how to obtain this track-level `id`, for now, it's good to know that you can fill out the identifier (`id`) into the search bar of Spotify to get to the song. For example, this is what `spotify:track:2EqlS6tkEnglzr7tkKAAYD` looks like:

# %% [markdown]
# <img src="images/spotify_search.gif" align="left" width=60%/>

# %% [markdown]
# **Let's try it out!**
# * Find the items associated with each of the following ids: `6oJ6le65B3SEqPwMRNXWjY` (track), `3fMbdgg4jU18AjLCKBhRSm` (artist), and `0IomjU2bXFng4LQBYn7Het` (album). Tip: depending on the type of collection, you may need to swap `track` for the respective collection you want to search for (e.g., `spotify:artist:{id}`).
#
# * What happens once you paste the API request URL (`https://api.spotify.com/v1/tracks/2EqlS6tkEnglzr7tkKAAYD`) into your browser? Why is that?

# %% [markdown]
# Next, we create a `headers` dictionary that contains the `access_token` and make a request to the API endpoint associated with the track `Come Together - Remastered 2009`:

# %%
headers = {
    "Authorization": f"Bearer {access_token}"
}

r = requests.get("https://api.spotify.com/v1/tracks/2EqlS6tkEnglzr7tkKAAYD", headers=headers)
r.json()
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#     'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#     'id': '3WrFJ7ztbogyGnTHbHJFl2',
#     'name': 'The Beatles',
#     'type': 'artist',
#     'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0ETFjACtuP2ADo6LFhL6HN'},
#   'href': 'https://api.spotify.com/v1/albums/0ETFjACtuP2ADo6LFhL6HN',
#   'id': '0ETFjACtuP2ADo6LFhL6HN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273dc30583ba717007b00cceb25',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02dc30583ba717007b00cceb25',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851dc30583ba717007b00cceb25',
#     'width': 64}],
#   'name': 'Abbey Road (Remastered)',
#   'release_date': '1969-09-26',
#   'release_date_precision': 'day',
#   'total_tracks': 17,
#   'type': 'album',
#   'uri': 'spotify:album:0ETFjACtuP2ADo6LFhL6HN'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#    'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#    'id': '3WrFJ7ztbogyGnTHbHJFl2',
#    'name': 'The Beatles',
#    'type': 'artist',
#    'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#  'available_markets': ['AD',
#   'AE',
#   'AL',
#   'AR',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BH',
#   'BO',
#   'BR',
#   'BY',
#   'CA',
#   'CH',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'GT',
#   'HK',
#   'HN',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IS',
#   'IT',
#   'JO',
#   'JP',
#   'KW',
#   'KZ',
#   'LB',
#   'LI',
#   'LT',
#   'LU',
#   'LV',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MK',
#   'MT',
#   'MX',
#   'MY',
#   'NI',
#   'NL',
#   'NO',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PH',
#   'PL',
#   'PS',
#   'PT',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SV',
#   'TH',
#   'TN',
#   'TR',
#   'TW',
#   'UA',
#   'US',
#   'UY',
#   'VN',
#   'XK',
#   'ZA'],
#  'disc_number': 1,
#  'duration_ms': 259946,
#  'explicit': False,
#  'external_ids': {'isrc': 'GBAYE0601690'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2EqlS6tkEnglzr7tkKAAYD'},
#  'href': 'https://api.spotify.com/v1/tracks/2EqlS6tkEnglzr7tkKAAYD',
#  'id': '2EqlS6tkEnglzr7tkKAAYD',
#  'is_local': False,
#  'name': 'Come Together - Remastered 2009',
#  'popularity': 80,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:2EqlS6tkEnglzr7tkKAAYD'}

# %% [markdown]
# As you can see, it returns a wide variety of information including the album (`Abbey Road (Remastered)`), artist (`The Beatles`), release date (26th of September 1969), total number of tracks on the album (`17`), duration (`259946` ms), popularity (`80`).
#
# Similarly, you could retrieve data from any of the following endpoints:
#
# | Endpoint | Usage | Returns |
# | :----- | :---- | :----- |
# | `/albums/{id}` | Get an album | Album name, total tracks, all seperate tracks, release date |
# | `/artists/{id}` | Get an artist | Artist, popularity, followers, and primary music genres |
# | `/artists/{id}/related-artists` | Get an artist's related artists | A list of artists with a similar music repertoire |
# | `/artists/{id}/albums` | Get an artist's albums | A list of albums from a given artist |
# | `/audio-features/{id}` | Get audio features for a track | Music characteristics (e.g., `loudness`, `energy`, `speechiness`) |

# %% [markdown]
# **Exercise 1**
# You are asked to conduct a market analysis of the listening behavior of The Beatles fans. Using one or more of the APIs above, compile a list of other related artists the fans frequently listen to. Rank the artists in terms of their popularity (see [API documentation](https://developer.spotify.com/documentation/web-api/reference/artists/get-artist/)). How do The Beatles rank overall? Tip: don't mix up the artist, album, and track ids!

# %%
# solution
from operator import itemgetter

r = requests.get("https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2/related-artists", headers=headers)
responses = r.json()

artists = {}
for artist in responses["artists"]:
    name = artist['name']
    popularity = artist['popularity']
    artists[name] = popularity
    
sorted(artists.items(), key=itemgetter(1), reverse=True)
# only Elvis Presley, The Rolling Stones, and Paul McCartney are more popular than The Beatles
# Out:
# [('Elvis Presley', 84),
#  ('The Rolling Stones', 82),
#  ('Paul McCartney', 81),
#  ('John Lennon', 80),
#  ('The Beach Boys', 78),
#  ('Bob Dylan', 77),
#  ('Chuck Berry', 76),
#  ('Eric Clapton', 76),
#  ('Simon & Garfunkel', 75),
#  ('Jimi Hendrix', 74),
#  ('George Harrison', 71),
#  ('The Kinks', 70),
#  ('Roy Orbison', 68),
#  ('Wings', 67),
#  ('The Hollies', 64),
#  ('Buddy Holly', 61),
#  ('The Byrds', 60),
#  ('Donovan', 60),
#  ('Badfinger', 57),
#  ('Ringo Starr', 55)]

# %% [markdown]
# **Exercise 2**
# A good friend of yours, a true Beatles fan for years, has asked you to take care of the music at his birthday party next week. In your search for tracks, you decide to consult the Spotify Web API and select the best dance numbers from the album `Abbey Road (Super Deluxe Edition)` to get the party going. Perform a comprehensive search query and argue which song should not be missed in any case. Give it a listen on Spotify, do you agree?

# %%
# solution
def retrieve_album_ids(artist_id):
    r = requests.get(f"https://api.spotify.com/v1/artists/{artist_id}/albums", headers=headers)
    albums = r.json()

    albums_dict = {}

    for album in albums["items"]: 
        album_id = album["id"]
        name = album["name"]
        albums_dict[name] = album_id
        
    return albums_dict


def retrieve_song_id_names(album_id):
    r = requests.get(f"https://api.spotify.com/v1/albums/{album_id}", headers=headers)
    songs_album = r.json()
    song_name_ids = {}

    for song in songs_album["tracks"]["items"]: 
        song_name_ids[song["id"]] = song["name"]
    
    return song_name_ids


def retrieve_audio_features(song_name_ids, feature="danceability"):
    features_songs = {}
    
    for song_id, song_name in song_name_ids.items():
        r = requests.get(f"https://api.spotify.com/v1/audio-features/{song_id}", headers=headers)
        audio_features = r.json()
        features_songs[song_name] = audio_features[feature]
        
    return features_songs


# retrieve a list of all album ids for the Beatles    
albums_dict = retrieve_album_ids("3WrFJ7ztbogyGnTHbHJFl2")

# obtain song ids for Abbey Road (Super Deluxe Edition) album
song_name_ids = retrieve_song_id_names(albums_dict['Abbey Road (Super Deluxe Edition)'])

# obtain danceability scores for songs
danceability_songs = retrieve_danceability_scores(song_name_ids)

print(f"The song with the highest danceabilty score: {max(danceability_songs, key=danceability_songs.get)}")
# Out:
# The song with the highest danceabilty score: Maxwell's Silver Hammer - 2019 Mix

# %% [markdown]
# ### 1.4 Multiple Query Parameters
# **Importance**
# By now, you have probably experienced how time-consuming it can to look up the `id` from a human-readable track or album name. Fortunately, there is a more efficient way by using the search endpoint. As we can derive from the [documentation](https://developer.spotify.com/documentation/web-api/reference/search/search/), it requires both a search query (`q`) and an item type (`type`). For example, we can easily obtain the track id of `Come Together - Remastered 2009` as follows (note that spaces are encoded as `+` (or the hex code `%20`), and the `q` and `type`  parameters are separated by a `&` symbol):

# %%
r = requests.get(f"https://api.spotify.com/v1/search?q=Come+Together+-+Remastered+2009&type=track", headers=headers)
search_request = r.json()
search_request
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Come+Together+-+Remastered+2009&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ETFjACtuP2ADo6LFhL6HN'},
#      'href': 'https://api.spotify.com/v1/albums/0ETFjACtuP2ADo6LFhL6HN',
#      'id': '0ETFjACtuP2ADo6LFhL6HN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc30583ba717007b00cceb25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc30583ba717007b00cceb25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc30583ba717007b00cceb25',
#        'width': 64}],
#      'name': 'Abbey Road (Remastered)',
#      'release_date': '1969-09-26',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:0ETFjACtuP2ADo6LFhL6HN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 259946,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE0601690'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2EqlS6tkEnglzr7tkKAAYD'},
#     'href': 'https://api.spotify.com/v1/tracks/2EqlS6tkEnglzr7tkKAAYD',
#     'id': '2EqlS6tkEnglzr7tkKAAYD',
#     'is_local': False,
#     'name': 'Come Together - Remastered 2009',
#     'popularity': 80,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2EqlS6tkEnglzr7tkKAAYD'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1cTeNkeINtXiaMLlashAKs'},
#      'href': 'https://api.spotify.com/v1/albums/1cTeNkeINtXiaMLlashAKs',
#      'id': '1cTeNkeINtXiaMLlashAKs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736e3d3c964df32136fb1cd594',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026e3d3c964df32136fb1cd594',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516e3d3c964df32136fb1cd594',
#        'width': 64}],
#      'name': 'The Beatles 1967 - 1970 (Remastered)',
#      'release_date': '1973-04-02',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:1cTeNkeINtXiaMLlashAKs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 2,
#     'duration_ms': 259666,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE0601690'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/71JkCL6msHDScuCKaJXFXP'},
#     'href': 'https://api.spotify.com/v1/tracks/71JkCL6msHDScuCKaJXFXP',
#     'id': '71JkCL6msHDScuCKaJXFXP',
#     'is_local': False,
#     'name': 'Come Together - Remastered 2009',
#     'popularity': 41,
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:71JkCL6msHDScuCKaJXFXP'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 2}}

# %% [markdown]
# **Let's try it out!**
# How many search results are there? Why is that? What's the difference between these results?

# %% [markdown]
# ---
# The [documentation](https://developer.spotify.com/documentation/web-api/reference/search/search/) is a great resource to learn more about how to refine your search queries. In the table below, we have summarized these guidelines:
#
# | Technique | Example | Interpretation |
# | :---- | :------ | :------------ |
# | Quotation | `q='Come+Together+2009'` | Matches with `Come Together (2009)` but not with `Come Together Remastered (2009)` |
# | Union | `q=2009+OR+Remastered+2009`| Matches with both `(2009)` and `Remastered (2009)`|
# | Exclusion | `q=Come+Together+2009+NOT+Remastered` | Matches with `Come Together (2009)` but not with `Come Together Remastered (2009)` |
# | Multiple queries | `q=track:Come+Together+artist:The+Beatles` | Matches with `Come Together` from `The Beatles` |
# | Multiple types | `q=Come+Together&type=album,track` | Matches with both `albums` and `tracks` named `Come Together`|
# | Genre | `q=Come+Together+genre:rock` | Matches with `rock` tracks named `Come Together` |
# | Year | `q=Come+Together+year:2009` | Matches with tracks named `Come Together` from `2009` |

# %% [markdown]
# **Exercise 3**
# Suppose that you have set yourself a goal to run half a marathon by the end of this year. Define an appropriate search strategy to find a collection of `workout` tracks aimed at runners that have been released this year. Since you don't want to continuously pick up your phone while running, the `album` should have listed at least 10 tracks. Note that a variety of solutions are possible here.

# %%
# solution
r = requests.get(f"https://api.spotify.com/v1/search?q=running+genre:workout+year:2021&type=track", headers=headers)
workout_tracks = r.json()

workout_albums = []

for workout_track in workout_tracks["tracks"]["items"]:
    if workout_track["album"]["total_tracks"] >= 10: 
        workout_albums.append(workout_track["album"]["name"])
        
print(workout_albums) # can you think of a plausible reason why there are so many duplicates?
# Out:
# ['Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)', 'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)']

# %%
# to avoid duplicates you may want to change for a different data-structure: a `set()`)
# its most important characteristic is that it only stores unique values
# to add an item to a set you use `.add()` as opposed to `.append()` for lists

workout_albums_set = set()

for workout_track in workout_tracks["tracks"]["items"]:
    if workout_track["album"]["total_tracks"] >= 10: 
        workout_albums_set.add(workout_track["album"]["name"])
        
print(workout_albums_set)
# Out:
# {'Happy Running Hits 2021 Workout Session (60 Minutes Non-Stop Mixed Compilation for Fitness & Workout 128 Bpm)'}

# %% [markdown]
# **Exercise 4**
# After listening to this running playlist for a while, you become more and more selective about the listed tracks. In particular, you find that although the rhythm of the tracks follow your ideal running pace (127-128 bpm), some of them lack a bit of energy. Hence, you decide to create a playlist yourself that only contains tracks with an `energy` level of at least `.8`. Pick one of the playlists from Exercise 3 and curate the selection of tracks that match your criterium.

# %%
# retrieve album id
r = requests.get(f"https://api.spotify.com/v1/search?q=happy+running+hits+2021+workout+session&type=album", headers=headers)
album = r.json()
album_id = album["albums"]["items"][0]["id"]

# get songs for album id (see Exercise 2)
album_tracks = retrieve_song_id_names(album_id)

# get audio feature for tracks (see Exercise 2)
energy_tracks =  retrieve_audio_features(album_tracks, "energy")
selected_tracks = []
    
# check whether track meet energy criteria
for track, energy in energy_tracks.items():
    if energy > .8: 
        selected_tracks.append(track)

print(selected_tracks)
# Out:
# ['Good As Hell - Workout Remix 128 Bpm', 'Everything I Wanted - Workout Remix 128 Bpm', 'Into The Unknown - Workout Remix 128 Bpm', 'Adore You - Workout Remix 128 Bpm', 'Hot Girl Bummer - Workout Remix 128 Bpm', 'South Of The Border - Workout Remix 128 Bpm', 'Memories - Workout Remix 128 Bpm', 'Ritmo (Bad Boys For Life) - Workout Remix 128 Bpm', 'So Am I - Workout Remix 128 Bpm', 'Trampoline - Workout Remix 128 Bpm', 'Roxanne - Workout Remix 128 Bpm', 'Nice To Meet Ya - Workout Remix 128 Bpm', 'Lose Control - Workout Remix 128 Bpm']

# %% [markdown]
# ### 1.5 Iterate over Pages

# %%
r = requests.get(f"https://api.spotify.com/v1/search?q=come+together&type=track", headers=headers)
search_results = r.json()
search_results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=come+together&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0ETFjACtuP2ADo6LFhL6HN'},
#      'href': 'https://api.spotify.com/v1/albums/0ETFjACtuP2ADo6LFhL6HN',
#      'id': '0ETFjACtuP2ADo6LFhL6HN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc30583ba717007b00cceb25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc30583ba717007b00cceb25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc30583ba717007b00cceb25',
#        'width': 64}],
#      'name': 'Abbey Road (Remastered)',
#      'release_date': '1969-09-26',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:0ETFjACtuP2ADo6LFhL6HN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 259946,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAYE0601690'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2EqlS6tkEnglzr7tkKAAYD'},
#     'href': 'https://api.spotify.com/v1/tracks/2EqlS6tkEnglzr7tkKAAYD',
#     'id': '2EqlS6tkEnglzr7tkKAAYD',
#     'is_local': False,
#     'name': 'Come Together - Remastered 2009',
#     'popularity': 80,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2EqlS6tkEnglzr7tkKAAYD'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01aC2ikO4Xgb2LUpf9JfKp'},
#        'href': 'https://api.spotify.com/v1/artists/01aC2ikO4Xgb2LUpf9JfKp',
#        'id': '01aC2ikO4Xgb2LUpf9JfKp',
#        'name': 'Gary Clark Jr.',
#        'type': 'artist',
#        'uri': 'spotify:artist:01aC2ikO4Xgb2LUpf9JfKp'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5svDnd8joFhbpbA3Ar0CfN'},
#        'href': 'https://api.spotify.com/v1/artists/5svDnd8joFhbpbA3Ar0CfN',
#        'id': '5svDnd8joFhbpbA3Ar0CfN',
#        'name': 'Junkie XL',
#        'type': 'artist',
#        'uri': 'spotify:artist:5svDnd8joFhbpbA3Ar0CfN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1FA0rfTpK5dost6Zk4pxjC'},
#      'href': 'https://api.spotify.com/v1/albums/1FA0rfTpK5dost6Zk4pxjC',
#      'id': '1FA0rfTpK5dost6Zk4pxjC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bce034d651da4d21e43c8a19',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bce034d651da4d21e43c8a19',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bce034d651da4d21e43c8a19',
#        'width': 64}],
#      'name': 'Come Together',
#      'release_date': '2017-09-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1FA0rfTpK5dost6Zk4pxjC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01aC2ikO4Xgb2LUpf9JfKp'},
#       'href': 'https://api.spotify.com/v1/artists/01aC2ikO4Xgb2LUpf9JfKp',
#       'id': '01aC2ikO4Xgb2LUpf9JfKp',
#       'name': 'Gary Clark Jr.',
#       'type': 'artist',
#       'uri': 'spotify:artist:01aC2ikO4Xgb2LUpf9JfKp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5svDnd8joFhbpbA3Ar0CfN'},
#       'href': 'https://api.spotify.com/v1/artists/5svDnd8joFhbpbA3Ar0CfN',
#       'id': '5svDnd8joFhbpbA3Ar0CfN',
#       'name': 'Junkie XL',
#       'type': 'artist',
#       'uri': 'spotify:artist:5svDnd8joFhbpbA3Ar0CfN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 193714,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11701415'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/45HAjqRWiNv6mMPw4NvZrU'},
#     'href': 'https://api.spotify.com/v1/tracks/45HAjqRWiNv6mMPw4NvZrU',
#     'id': '45HAjqRWiNv6mMPw4NvZrU',
#     'is_local': False,
#     'name': 'Come Together',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/31ea5e41d9af8a261c3f9153a2c964c314a7dec5?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:45HAjqRWiNv6mMPw4NvZrU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#        'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#        'id': '7bXgB6jMjp9ATFy66eO08Z',
#        'name': 'Chris Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1BfLzaTFI5qKsAAk0Ae6aV'},
#      'href': 'https://api.spotify.com/v1/albums/1BfLzaTFI5qKsAAk0Ae6aV',
#      'id': '1BfLzaTFI5qKsAAk0Ae6aV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739e588b0c2afe8178b2b76231',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029e588b0c2afe8178b2b76231',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519e588b0c2afe8178b2b76231',
#        'width': 64}],
#      'name': 'Indigo',
#      'release_date': '2019-06-28',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:1BfLzaTFI5qKsAAk0Ae6aV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#       'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#       'id': '7bXgB6jMjp9ATFy66eO08Z',
#       'name': 'Chris Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7RZ31TRPVadSFVy1o8os'},
#       'href': 'https://api.spotify.com/v1/artists/3Y7RZ31TRPVadSFVy1o8os',
#       'id': '3Y7RZ31TRPVadSFVy1o8os',
#       'name': 'H.E.R.',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y7RZ31TRPVadSFVy1o8os'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 234146,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11901570'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1IRU2kqvCmmySoB0ywJTmI'},
#     'href': 'https://api.spotify.com/v1/tracks/1IRU2kqvCmmySoB0ywJTmI',
#     'id': '1IRU2kqvCmmySoB0ywJTmI',
#     'is_local': False,
#     'name': 'Come Together (feat. H.E.R.)',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/47d20a6542cd0e603b5b977d3dd09e0a2609dfb9?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1IRU2kqvCmmySoB0ywJTmI'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ey4PD4MYsKc5I2dolUwbH'},
#        'href': 'https://api.spotify.com/v1/artists/7Ey4PD4MYsKc5I2dolUwbH',
#        'id': '7Ey4PD4MYsKc5I2dolUwbH',
#        'name': 'Aerosmith',
#        'type': 'artist',
#        'uri': 'spotify:artist:7Ey4PD4MYsKc5I2dolUwbH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6IXRrteQyjBXc40XlIhnD3'},
#      'href': 'https://api.spotify.com/v1/albums/6IXRrteQyjBXc40XlIhnD3',
#      'id': '6IXRrteQyjBXc40XlIhnD3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737d940e9a816ffe006db9d6d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027d940e9a816ffe006db9d6d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517d940e9a816ffe006db9d6d0',
#        'width': 64}],
#      'name': "Aerosmith's Greatest Hits",
#      'release_date': '1980-11-11',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6IXRrteQyjBXc40XlIhnD3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7Ey4PD4MYsKc5I2dolUwbH'},
#       'href': 'https://api.spotify.com/v1/artists/7Ey4PD4MYsKc5I2dolUwbH',
#       'id': '7Ey4PD4MYsKc5I2dolUwbH',
#       'name': 'Aerosmith',
#       'type': 'artist',
#       'uri': 'spotify:artist:7Ey4PD4MYsKc5I2dolUwbH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 224600,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10024252'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5OkZtvqYLkgy5ri5Ms6WBz'},
#     'href': 'https://api.spotify.com/v1/tracks/5OkZtvqYLkgy5ri5Ms6WBz',
#     'id': '5OkZtvqYLkgy5ri5Ms6WBz',
#     'is_local': False,
#     'name': 'Come Together',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4bb928e766c672cdbecb98f42c9dd6b73621906e?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:5OkZtvqYLkgy5ri5Ms6WBz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GN9PivdemQRKjDt4z5Zv8'},
#        'href': 'https://api.spotify.com/v1/artists/7GN9PivdemQRKjDt4z5Zv8',
#        'id': '7GN9PivdemQRKjDt4z5Zv8',
#        'name': 'The Internet',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GN9PivdemQRKjDt4z5Zv8'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/27ThgFMUAx3MXLQ297DzWF'},
#      'href': 'https://api.spotify.com/v1/albums/27ThgFMUAx3MXLQ297DzWF',
#      'id': '27ThgFMUAx3MXLQ297DzWF',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27360de86e634f2bd4d1364797e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0260de86e634f2bd4d1364797e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485160de86e634f2bd4d1364797e',
#        'width': 64}],
#      'name': 'Hive Mind',
#      'release_date': '2018-07-20',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:27ThgFMUAx3MXLQ297DzWF'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GN9PivdemQRKjDt4z5Zv8'},
#       'href': 'https://api.spotify.com/v1/artists/7GN9PivdemQRKjDt4z5Zv8',
#       'id': '7GN9PivdemQRKjDt4z5Zv8',
#       'name': 'The Internet',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GN9PivdemQRKjDt4z5Zv8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 220586,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM11804478'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1l32mo5oW5oIRRjNnVJBNR'},
#     'href': 'https://api.spotify.com/v1/tracks/1l32mo5oW5oIRRjNnVJBNR',
#     'id': '1l32mo5oW5oIRRjNnVJBNR',
#     'is_local': False,
#     'name': 'Come Together',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4fbdcb7c6426fc675fc26e8850c7edb144445017?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1l32mo5oW5oIRRjNnVJBNR'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6gZq1Q6bdOxsUPUG1TaFbF'},
#        'href': 'https://api.spotify.com/v1/artists/6gZq1Q6bdOxsUPUG1TaFbF',
#        'id': '6gZq1Q6bdOxsUPUG1TaFbF',
#        'name': 'Godsmack',
#        'type': 'artist',
#        'uri': 'spotify:artist:6gZq1Q6bdOxsUPUG1TaFbF'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4qq3w5Bfb46Rw9kE6QSYNT'},
#      'href': 'https://api.spotify.com/v1/albums/4qq3w5Bfb46Rw9kE6QSYNT',
#      'id': '4qq3w5Bfb46Rw9kE6QSYNT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cfa953e2e325adb6402e0ff8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cfa953e2e325adb6402e0ff8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cfa953e2e325adb6402e0ff8',
#        'width': 64}],
#      'name': 'Live & Inspired',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4qq3w5Bfb46Rw9kE6QSYNT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6gZq1Q6bdOxsUPUG1TaFbF'},
#       'href': 'https://api.spotify.com/v1/artists/6gZq1Q6bdOxsUPUG1TaFbF',
#       'id': '6gZq1Q6bdOxsUPUG1TaFbF',
#       'name': 'Godsmack',
#       'type': 'artist',
#       'uri': 'spotify:artist:6gZq1Q6bdOxsUPUG1TaFbF'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 2,
#     'duration_ms': 226293,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71203826'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/02LrmnkHvOcQo6L2RBdfqu'},
#     'href': 'https://api.spotify.com/v1/tracks/02LrmnkHvOcQo6L2RBdfqu',
#     'id': '02LrmnkHvOcQo6L2RBdfqu',
#     'is_local': False,
#     'name': 'Come Together - Live From Fox Theatre Detroit, MI/2012',
#     'popularity': 49,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:02LrmnkHvOcQo6L2RBdfqu'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5iT3F2EhjVQVrO4PKhsP8c'},
#      'href': 'https://api.spotify.com/v1/albums/5iT3F2EhjVQVrO4PKhsP8c',
#      'id': '5iT3F2EhjVQVrO4PKhsP8c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c94603dcb78ec39322cebb5b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c94603dcb78ec39322cebb5b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c94603dcb78ec39322cebb5b',
#        'width': 64}],
#      'name': 'Abbey Road (Super Deluxe Edition)',
#      'release_date': '2019-09-27',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:5iT3F2EhjVQVrO4PKhsP8c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 260200,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71903329'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6lSxM9BKcEZBSDKl2VODsF'},
#     'href': 'https://api.spotify.com/v1/tracks/6lSxM9BKcEZBSDKl2VODsF',
#     'id': '6lSxM9BKcEZBSDKl2VODsF',
#     'is_local': False,
#     'name': 'Come Together - 2019 Mix',
#     'popularity': 56,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6lSxM9BKcEZBSDKl2VODsF'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#        'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#        'id': '3WrFJ7ztbogyGnTHbHJFl2',
#        'name': 'The Beatles',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7vEJAtP3KgKSpOHVgwm3Eh'},
#      'href': 'https://api.spotify.com/v1/albums/7vEJAtP3KgKSpOHVgwm3Eh',
#      'id': '7vEJAtP3KgKSpOHVgwm3Eh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273582d56ce20fe0146ffa0e5cf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02582d56ce20fe0146ffa0e5cf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851582d56ce20fe0146ffa0e5cf',
#        'width': 64}],
#      'name': '1 (Remastered)',
#      'release_date': '2000-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:7vEJAtP3KgKSpOHVgwm3Eh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 258693,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71505891'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3CEFDHJSiERlfwRujZ1CkJ'},
#     'href': 'https://api.spotify.com/v1/tracks/3CEFDHJSiERlfwRujZ1CkJ',
#     'id': '3CEFDHJSiERlfwRujZ1CkJ',
#     'is_local': False,
#     'name': 'Come Together - Remastered 2015',
#     'popularity': 56,
#     'preview_url': None,
#     'track_number': 25,
#     'type': 'track',
#     'uri': 'spotify:track:3CEFDHJSiERlfwRujZ1CkJ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q9g9l3NqzvllaYFTmSYYv'},
#        'href': 'https://api.spotify.com/v1/artists/4Q9g9l3NqzvllaYFTmSYYv',
#        'id': '4Q9g9l3NqzvllaYFTmSYYv',
#        'name': 'Rodney "Darkchild" Jerkins',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Q9g9l3NqzvllaYFTmSYYv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6xV8VECyJrKC7MdlXgI74e'},
#      'href': 'https://api.spotify.com/v1/albums/6xV8VECyJrKC7MdlXgI74e',
#      'id': '6xV8VECyJrKC7MdlXgI74e',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273caf5bf42ab9867e3ec6305bb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02caf5bf42ab9867e3ec6305bb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851caf5bf42ab9867e3ec6305bb',
#        'width': 64}],
#      'name': 'Come Together',
#      'release_date': '2020-04-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6xV8VECyJrKC7MdlXgI74e'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Q9g9l3NqzvllaYFTmSYYv'},
#       'href': 'https://api.spotify.com/v1/artists/4Q9g9l3NqzvllaYFTmSYYv',
#       'id': '4Q9g9l3NqzvllaYFTmSYYv',
#       'name': 'Rodney "Darkchild" Jerkins',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Q9g9l3NqzvllaYFTmSYYv'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3JuIdxCPSDG9oVk9Z4kR4g'},
#       'href': 'https://api.spotify.com/v1/artists/3JuIdxCPSDG9oVk9Z4kR4g',
#       'id': '3JuIdxCPSDG9oVk9Z4kR4g',
#       'name': 'Tim Bowman Jr',
#       'type': 'artist',
#       'uri': 'spotify:artist:3JuIdxCPSDG9oVk9Z4kR4g'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2erWQ9iYMlXEIPiYa25N7E'},
#       'href': 'https://api.spotify.com/v1/artists/2erWQ9iYMlXEIPiYa25N7E',
#       'id': '2erWQ9iYMlXEIPiYa25N7E',
#       'name': 'Joy Enriquez',
#       'type': 'artist',
#       'uri': 'spotify:artist:2erWQ9iYMlXEIPiYa25N7E'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4akybxRTGHJZ1DXjLhJ1qu'},
#       'href': 'https://api.spotify.com/v1/artists/4akybxRTGHJZ1DXjLhJ1qu',
#       'id': '4akybxRTGHJZ1DXjLhJ1qu',
#       'name': 'Kirk Franklin',
#       'type': 'artist',
#       'uri': 'spotify:artist:4akybxRTGHJZ1DXjLhJ1qu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1G73Usb8ZrWsOSxOmufR3D'},
#       'href': 'https://api.spotify.com/v1/artists/1G73Usb8ZrWsOSxOmufR3D',
#       'id': '1G73Usb8ZrWsOSxOmufR3D',
#       'name': 'Kelontae Gavin',
#       'type': 'artist',
#       'uri': 'spotify:artist:1G73Usb8ZrWsOSxOmufR3D'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ndyVAdV9UqF1XjyTJt484'},
#       'href': 'https://api.spotify.com/v1/artists/2ndyVAdV9UqF1XjyTJt484',
#       'id': '2ndyVAdV9UqF1XjyTJt484',
#       'name': 'Fred Hammond',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ndyVAdV9UqF1XjyTJt484'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6PLnvS24SZA2hJxI1Sf88o'},
#       'href': 'https://api.spotify.com/v1/artists/6PLnvS24SZA2hJxI1Sf88o',
#       'id': '6PLnvS24SZA2hJxI1Sf88o',
#       'name': 'Heavenly Joy',
#       'type': 'artist',
#       'uri': 'spotify:artist:6PLnvS24SZA2hJxI1Sf88o'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5gpgMHIDzhdGccwJniIXrh'},
#       'href': 'https://api.spotify.com/v1/artists/5gpgMHIDzhdGccwJniIXrh',
#       'id': '5gpgMHIDzhdGccwJniIXrh',
#       'name': "Le'Andria Johnson",
#       'type': 'artist',
#       'uri': 'spotify:artist:5gpgMHIDzhdGccwJniIXrh'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1CFCsEqKrCyvAFKOATQHiW'},
#       'href': 'https://api.spotify.com/v1/artists/1CFCsEqKrCyvAFKOATQHiW',
#       'id': '1CFCsEqKrCyvAFKOATQHiW',
#       'name': 'Lecrae',
#       'type': 'artist',
#       'uri': 'spotify:artist:1CFCsEqKrCyvAFKOATQHiW'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/12Kgt2eahvxNWhD5PnSUde'},
#       'href': 'https://api.spotify.com/v1/artists/12Kgt2eahvxNWhD5PnSUde',
#       'id': '12Kgt2eahvxNWhD5PnSUde',
#       'name': 'Mary Mary',
#       'type': 'artist',
#       'uri': 'spotify:artist:12Kgt2eahvxNWhD5PnSUde'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/172Nbc7kz4JhcCor54l9Sr'},
#       'href': 'https://api.spotify.com/v1/artists/172Nbc7kz4JhcCor54l9Sr',
#       'id': '172Nbc7kz4JhcCor54l9Sr',
#       'name': 'Jac Ross',
#       'type': 'artist',
#       'uri': 'spotify:artist:172Nbc7kz4JhcCor54l9Sr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5r0KYGxdIZEHZ6z6XbkVbo'},
#       'href': 'https://api.spotify.com/v1/artists/5r0KYGxdIZEHZ6z6XbkVbo',
#       'id': '5r0KYGxdIZEHZ6z6XbkVbo',
#       'name': 'Marvin Sapp',
#       'type': 'artist',
#       'uri': 'spotify:artist:5r0KYGxdIZEHZ6z6XbkVbo'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/76dDIM8amCY58U3uvr1Rw1'},
#       'href': 'https://api.spotify.com/v1/artists/76dDIM8amCY58U3uvr1Rw1',
#       'id': '76dDIM8amCY58U3uvr1Rw1',
#       'name': 'Karen Clark Sheard',
#       'type': 'artist',
#       'uri': 'spotify:artist:76dDIM8amCY58U3uvr1Rw1'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4x3CdMQ3YjnPn4Evhyni5y'},
#       'href': 'https://api.spotify.com/v1/artists/4x3CdMQ3YjnPn4Evhyni5y',
#       'id': '4x3CdMQ3YjnPn4Evhyni5y',
#       'name': 'Kierra Sheard',
#       'type': 'artist',
#       'uri': 'spotify:artist:4x3CdMQ3YjnPn4Evhyni5y'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7cvQ26Fz2sz3iMcAc8HXaD'},
#       'href': 'https://api.spotify.com/v1/artists/7cvQ26Fz2sz3iMcAc8HXaD',
#       'id': '7cvQ26Fz2sz3iMcAc8HXaD',
#       'name': 'Shelby 5',
#       'type': 'artist',
#       'uri': 'spotify:artist:7cvQ26Fz2sz3iMcAc8HXaD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 346096,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA5W2000098'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7DpfOkks38EfsrVcG9Zmhw'},
#     'href': 'https://api.spotify.com/v1/tracks/7DpfOkks38EfsrVcG9Zmhw',
#     'id': '7DpfOkks38EfsrVcG9Zmhw',
#     'is_local': False,
#     'name': 'Come Together',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ea5f2b14d7bda4f5102c4c15b8c929d7f107f9b2?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7DpfOkks38EfsrVcG9Zmhw'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29q1axQPERERxUzqufXMqB'},
#        'href': 'https://api.spotify.com/v1/artists/29q1axQPERERxUzqufXMqB',
#        'id': '29q1axQPERERxUzqufXMqB',
#        'name': 'together PANGEA',
#        'type': 'artist',
#        'uri': 'spotify:artist:29q1axQPERERxUzqufXMqB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3saoeCU4gzjMKCLKczIhn6'},
#      'href': 'https://api.spotify.com/v1/albums/3saoeCU4gzjMKCLKczIhn6',
#      'id': '3saoeCU4gzjMKCLKczIhn6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730be16f4631e1485f9587e220',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020be16f4631e1485f9587e220',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510be16f4631e1485f9587e220',
#        'width': 64}],
#      'name': 'Living Dummy',
#      'release_date': '2011-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3saoeCU4gzjMKCLKczIhn6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/29q1axQPERERxUzqufXMqB'},
#       'href': 'https://api.spotify.com/v1/artists/29q1axQPERERxUzqufXMqB',
#       'id': '29q1axQPERERxUzqufXMqB',
#       'name': 'together PANGEA',
#       'type': 'artist',
#       'uri': 'spotify:artist:29q1axQPERERxUzqufXMqB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 150152,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCABH1229163'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/71U7k9l1euqfmGMiAddU9O'},
#     'href': 'https://api.spotify.com/v1/tracks/71U7k9l1euqfmGMiAddU9O',
#     'id': '71U7k9l1euqfmGMiAddU9O',
#     'is_local': False,
#     'name': 'Too Drunk to Come',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/255a5a101d3755e0edb4b447573552634c238be6?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:71U7k9l1euqfmGMiAddU9O'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h3rSZ8VLK7a5vXjEmhfuD'},
#        'href': 'https://api.spotify.com/v1/artists/6h3rSZ8VLK7a5vXjEmhfuD',
#        'id': '6h3rSZ8VLK7a5vXjEmhfuD',
#        'name': 'The Brothers Johnson',
#        'type': 'artist',
#        'uri': 'spotify:artist:6h3rSZ8VLK7a5vXjEmhfuD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5IzEY3pod97kHrdt5Qt1RB'},
#      'href': 'https://api.spotify.com/v1/albums/5IzEY3pod97kHrdt5Qt1RB',
#      'id': '5IzEY3pod97kHrdt5Qt1RB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273537ebc1940f248ab6f1b42f3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02537ebc1940f248ab6f1b42f3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851537ebc1940f248ab6f1b42f3',
#        'width': 64}],
#      'name': 'Look Out For #1',
#      'release_date': '1976-01-01',
# ...
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#        'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#        'id': '7bXgB6jMjp9ATFy66eO08Z',
#        'name': 'Chris Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3okhA6w5uau6ZNhnVpwVww'},
#      'href': 'https://api.spotify.com/v1/albums/3okhA6w5uau6ZNhnVpwVww',
#      'id': '3okhA6w5uau6ZNhnVpwVww',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739a494f7d8909a6cc4ceb74ac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029a494f7d8909a6cc4ceb74ac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519a494f7d8909a6cc4ceb74ac',
#        'width': 64}],
#      'name': 'Indigo (Extended)',
#      'release_date': '2019-10-04',
#      'release_date_precision': 'day',
#      'total_tracks': 42,
#      'type': 'album',
#      'uri': 'spotify:album:3okhA6w5uau6ZNhnVpwVww'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#       'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#       'id': '7bXgB6jMjp9ATFy66eO08Z',
#       'name': 'Chris Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y7RZ31TRPVadSFVy1o8os'},
#       'href': 'https://api.spotify.com/v1/artists/3Y7RZ31TRPVadSFVy1o8os',
#       'id': '3Y7RZ31TRPVadSFVy1o8os',
#       'name': 'H.E.R.',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y7RZ31TRPVadSFVy1o8os'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 234146,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11901570'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0tgyi5mvvPNEZYUp5v5Qs1'},
#     'href': 'https://api.spotify.com/v1/tracks/0tgyi5mvvPNEZYUp5v5Qs1',
#     'id': '0tgyi5mvvPNEZYUp5v5Qs1',
#     'is_local': False,
#     'name': 'Come Together (feat. H.E.R.)',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/47d20a6542cd0e603b5b977d3dd09e0a2609dfb9?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:0tgyi5mvvPNEZYUp5v5Qs1'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Kjl91bg9I6TuhrEC0NQgX'},
#        'href': 'https://api.spotify.com/v1/artists/4Kjl91bg9I6TuhrEC0NQgX',
#        'id': '4Kjl91bg9I6TuhrEC0NQgX',
#        'name': 'Urbandawn',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Kjl91bg9I6TuhrEC0NQgX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3esBGleyjp8v5QZI8RToXK'},
#      'href': 'https://api.spotify.com/v1/albums/3esBGleyjp8v5QZI8RToXK',
#      'id': '3esBGleyjp8v5QZI8RToXK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366374fc78361eac0e11c5345',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266374fc78361eac0e11c5345',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166374fc78361eac0e11c5345',
#        'width': 64}],
#      'name': 'Come Together (feat. Tyson Kelly)',
#      'release_date': '2019-05-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3esBGleyjp8v5QZI8RToXK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Kjl91bg9I6TuhrEC0NQgX'},
#       'href': 'https://api.spotify.com/v1/artists/4Kjl91bg9I6TuhrEC0NQgX',
#       'id': '4Kjl91bg9I6TuhrEC0NQgX',
#       'name': 'Urbandawn',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Kjl91bg9I6TuhrEC0NQgX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3UZp4Jv5flsRprbySTTZkD'},
#       'href': 'https://api.spotify.com/v1/artists/3UZp4Jv5flsRprbySTTZkD',
#       'id': '3UZp4Jv5flsRprbySTTZkD',
#       'name': 'Tyson Kelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:3UZp4Jv5flsRprbySTTZkD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 238959,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCJY1900085'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4pd8nt4rexiPsqLzo3daFv'},
#     'href': 'https://api.spotify.com/v1/tracks/4pd8nt4rexiPsqLzo3daFv',
#     'id': '4pd8nt4rexiPsqLzo3daFv',
#     'is_local': False,
#     'name': 'Come Together',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1c7105a675affd90bfa82bd19c5c242d3f556320?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4pd8nt4rexiPsqLzo3daFv'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1UdQqCUR7RwB9YYJONwbdM'},
#        'href': 'https://api.spotify.com/v1/artists/1UdQqCUR7RwB9YYJONwbdM',
#        'id': '1UdQqCUR7RwB9YYJONwbdM',
#        'name': 'Trapt',
#        'type': 'artist',
#        'uri': 'spotify:artist:1UdQqCUR7RwB9YYJONwbdM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1FQC0Fv2j7Q0sbFre0Z67a'},
#      'href': 'https://api.spotify.com/v1/albums/1FQC0Fv2j7Q0sbFre0Z67a',
#      'id': '1FQC0Fv2j7Q0sbFre0Z67a',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738f85d796ca89bc5513f38fb9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028f85d796ca89bc5513f38fb9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518f85d796ca89bc5513f38fb9',
#        'width': 64}],
#      'name': 'Come Together (feat. AN0MALY)',
#      'release_date': '2018-11-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1FQC0Fv2j7Q0sbFre0Z67a'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1UdQqCUR7RwB9YYJONwbdM'},
#       'href': 'https://api.spotify.com/v1/artists/1UdQqCUR7RwB9YYJONwbdM',
#       'id': '1UdQqCUR7RwB9YYJONwbdM',
#       'name': 'Trapt',
#       'type': 'artist',
#       'uri': 'spotify:artist:1UdQqCUR7RwB9YYJONwbdM'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7i9L9EAcbxFQgViNo5LW7I'},
#       'href': 'https://api.spotify.com/v1/artists/7i9L9EAcbxFQgViNo5LW7I',
#       'id': '7i9L9EAcbxFQgViNo5LW7I',
#       'name': 'An0maly',
#       'type': 'artist',
#       'uri': 'spotify:artist:7i9L9EAcbxFQgViNo5LW7I'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 236758,
#     'explicit': False,
#     'external_ids': {'isrc': 'USDXS1805784'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6mViUbtdoteINeidXdpF9g'},
#     'href': 'https://api.spotify.com/v1/tracks/6mViUbtdoteINeidXdpF9g',
#     'id': '6mViUbtdoteINeidXdpF9g',
#     'is_local': False,
#     'name': 'Come Together (feat. AN0MALY)',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/83b9331fac5ecaeeb4777c2e634a75211b74be61?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6mViUbtdoteINeidXdpF9g'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6gZq1Q6bdOxsUPUG1TaFbF'},
#        'href': 'https://api.spotify.com/v1/artists/6gZq1Q6bdOxsUPUG1TaFbF',
#        'id': '6gZq1Q6bdOxsUPUG1TaFbF',
#        'name': 'Godsmack',
#        'type': 'artist',
#        'uri': 'spotify:artist:6gZq1Q6bdOxsUPUG1TaFbF'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6QOoJkjaJw5mp6FUp6KCkN'},
#      'href': 'https://api.spotify.com/v1/albums/6QOoJkjaJw5mp6FUp6KCkN',
#      'id': '6QOoJkjaJw5mp6FUp6KCkN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c3234a7edbf0677fbf83bb03',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c3234a7edbf0677fbf83bb03',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c3234a7edbf0677fbf83bb03',
#        'width': 64}],
#      'name': 'Live & Inspired',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6QOoJkjaJw5mp6FUp6KCkN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6gZq1Q6bdOxsUPUG1TaFbF'},
#       'href': 'https://api.spotify.com/v1/artists/6gZq1Q6bdOxsUPUG1TaFbF',
#       'id': '6gZq1Q6bdOxsUPUG1TaFbF',
#       'name': 'Godsmack',
#       'type': 'artist',
#       'uri': 'spotify:artist:6gZq1Q6bdOxsUPUG1TaFbF'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 2,
#     'duration_ms': 226293,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71203826'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/30KaTTGsHO8z9esyfuJuU6'},
#     'href': 'https://api.spotify.com/v1/tracks/30KaTTGsHO8z9esyfuJuU6',
#     'id': '30KaTTGsHO8z9esyfuJuU6',
#     'is_local': False,
#     'name': 'Come Together',
#     'popularity': 36,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:30KaTTGsHO8z9esyfuJuU6'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=come+together&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 7094}}

# %% [markdown]
# &limit=50, &offset
# zonder dat je het doorhad maar klein een deel van de zoekresultaten gezien -> iterate over pages
#
# gaandeweg wordt je steeds beter in hard lopen -> nu playlists die minstens 100 songs

# %%
previous: offset=0 -> offset=20 -> next: offset=40

# %%
narrow down to running tracks
# Out:
# '20 Retro Club Hits'

# %%
r = requests.get(f"https://api.spotify.com/v1/search?q=genre:workout+year:2021&type=track&offset=20", headers=headers)
workout_tracks = r.json()
workout_tracks
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=genre%3Aworkout+year%3A2021&type=track&offset=20&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ihvWb92Gjq0KbRScprmFp'},
#      'href': 'https://api.spotify.com/v1/albums/2ihvWb92Gjq0KbRScprmFp',
#      'id': '2ihvWb92Gjq0KbRScprmFp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6fb546a02ff0f3fe760fc53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6fb546a02ff0f3fe760fc53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6fb546a02ff0f3fe760fc53',
#        'width': 64}],
#      'name': '31 Power Workouts',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:2ihvWb92Gjq0KbRScprmFp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 205600,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83868092'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6dutmajJD8GcIMaYOdZBze'},
#     'href': 'https://api.spotify.com/v1/tracks/6dutmajJD8GcIMaYOdZBze',
#     'id': '6dutmajJD8GcIMaYOdZBze',
#     'is_local': False,
#     'name': 'Legacy',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bdfeee0be2729ac75951a4d0c761963ca5a64121?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6dutmajJD8GcIMaYOdZBze'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BzLbN9yomNn0cNE1sChPB'},
#        'href': 'https://api.spotify.com/v1/artists/4BzLbN9yomNn0cNE1sChPB',
#        'id': '4BzLbN9yomNn0cNE1sChPB',
#        'name': 'Workout Dance Factory',
#        'type': 'artist',
#        'uri': 'spotify:artist:4BzLbN9yomNn0cNE1sChPB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6qXOF0CRXX0lBLzvFWSmbZ'},
#      'href': 'https://api.spotify.com/v1/albums/6qXOF0CRXX0lBLzvFWSmbZ',
#      'id': '6qXOF0CRXX0lBLzvFWSmbZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bb8e93160e7c859c7b1c3b3d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bb8e93160e7c859c7b1c3b3d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bb8e93160e7c859c7b1c3b3d',
#        'width': 64}],
#      'name': '21 Workout Hits',
#      'release_date': '2021-01-02',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6qXOF0CRXX0lBLzvFWSmbZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BzLbN9yomNn0cNE1sChPB'},
#       'href': 'https://api.spotify.com/v1/artists/4BzLbN9yomNn0cNE1sChPB',
#       'id': '4BzLbN9yomNn0cNE1sChPB',
#       'name': 'Workout Dance Factory',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BzLbN9yomNn0cNE1sChPB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212812,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83867847'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7vJF0nBiGqTz2E3aYnboV3'},
#     'href': 'https://api.spotify.com/v1/tracks/7vJF0nBiGqTz2E3aYnboV3',
#     'id': '7vJF0nBiGqTz2E3aYnboV3',
#     'is_local': False,
#     'name': 'Pump It',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3d9481f31fda7bb224ddf52ed04c70c1b3ec933e?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7vJF0nBiGqTz2E3aYnboV3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4n7nJMEY5cuQntfrmTiFh3'},
#      'href': 'https://api.spotify.com/v1/albums/4n7nJMEY5cuQntfrmTiFh3',
#      'id': '4n7nJMEY5cuQntfrmTiFh3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bd3e83acd53b6b80eb70c373',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bd3e83acd53b6b80eb70c373',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bd3e83acd53b6b80eb70c373',
#        'width': 64}],
#      'name': '31 Pumped Up Workouts',
#      'release_date': '2021-01-02',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:4n7nJMEY5cuQntfrmTiFh3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 193600,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83867990'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0BNEZND0U3vkG06OlLss2g'},
#     'href': 'https://api.spotify.com/v1/tracks/0BNEZND0U3vkG06OlLss2g',
#     'id': '0BNEZND0U3vkG06OlLss2g',
#     'is_local': False,
#     'name': 'Expand',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ed5af66506e4eb2413b0f1598c9e0b93dc7d8bb6?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0BNEZND0U3vkG06OlLss2g'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ihvWb92Gjq0KbRScprmFp'},
#      'href': 'https://api.spotify.com/v1/albums/2ihvWb92Gjq0KbRScprmFp',
#      'id': '2ihvWb92Gjq0KbRScprmFp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6fb546a02ff0f3fe760fc53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6fb546a02ff0f3fe760fc53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6fb546a02ff0f3fe760fc53',
#        'width': 64}],
#      'name': '31 Power Workouts',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:2ihvWb92Gjq0KbRScprmFp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 206000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83868098'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0M0se7dLxADfUpF487jao0'},
#     'href': 'https://api.spotify.com/v1/tracks/0M0se7dLxADfUpF487jao0',
#     'id': '0M0se7dLxADfUpF487jao0',
#     'is_local': False,
#     'name': 'Pulse',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e441df71d73265a4915ed3f54da77ca2ed8c9a06?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:0M0se7dLxADfUpF487jao0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4n7nJMEY5cuQntfrmTiFh3'},
#      'href': 'https://api.spotify.com/v1/albums/4n7nJMEY5cuQntfrmTiFh3',
#      'id': '4n7nJMEY5cuQntfrmTiFh3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bd3e83acd53b6b80eb70c373',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bd3e83acd53b6b80eb70c373',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bd3e83acd53b6b80eb70c373',
#        'width': 64}],
#      'name': '31 Pumped Up Workouts',
#      'release_date': '2021-01-02',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:4n7nJMEY5cuQntfrmTiFh3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 187034,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83867923'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1CdZLiF3ObuTjae15Q7pq3'},
#     'href': 'https://api.spotify.com/v1/tracks/1CdZLiF3ObuTjae15Q7pq3',
#     'id': '1CdZLiF3ObuTjae15Q7pq3',
#     'is_local': False,
#     'name': 'The Pump',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/52f0e40179d718e738073767900f9ca6276fd6fd?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 22,
#     'type': 'track',
#     'uri': 'spotify:track:1CdZLiF3ObuTjae15Q7pq3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6L74J3BzylQkJF7rBXTpgT'},
#        'href': 'https://api.spotify.com/v1/artists/6L74J3BzylQkJF7rBXTpgT',
#        'id': '6L74J3BzylQkJF7rBXTpgT',
#        'name': 'SuperFitness',
#        'type': 'artist',
#        'uri': 'spotify:artist:6L74J3BzylQkJF7rBXTpgT'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6l23UXashjTR5XndEIdFng'},
#      'href': 'https://api.spotify.com/v1/albums/6l23UXashjTR5XndEIdFng',
#      'id': '6l23UXashjTR5XndEIdFng',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739fd2a111d004f63b4a33212c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029fd2a111d004f63b4a33212c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519fd2a111d004f63b4a33212c',
#        'width': 64}],
#      'name': 'Aerobic Hits Session 2021: 60 Minutes Mixed for Fitness & Workout 135 bpm/32 Count',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:6l23UXashjTR5XndEIdFng'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6L74J3BzylQkJF7rBXTpgT'},
#       'href': 'https://api.spotify.com/v1/artists/6L74J3BzylQkJF7rBXTpgT',
#       'id': '6L74J3BzylQkJF7rBXTpgT',
#       'name': 'SuperFitness',
#       'type': 'artist',
#       'uri': 'spotify:artist:6L74J3BzylQkJF7rBXTpgT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 227550,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES50A2000645'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UuaHpK5y3QrsdHFSbslLo'},
#     'href': 'https://api.spotify.com/v1/tracks/1UuaHpK5y3QrsdHFSbslLo',
#     'id': '1UuaHpK5y3QrsdHFSbslLo',
#     'is_local': False,
#     'name': "OMG What's Happening - Workout Remix 135 bpm",
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/275f24c514ade53173f46aeab00f6661f7182e0e?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:1UuaHpK5y3QrsdHFSbslLo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WcnnHSRP40h3KJ7In8rAX'},
#        'href': 'https://api.spotify.com/v1/artists/4WcnnHSRP40h3KJ7In8rAX',
#        'id': '4WcnnHSRP40h3KJ7In8rAX',
#        'name': 'Fitness Workout Hits',
#        'type': 'artist',
#        'uri': 'spotify:artist:4WcnnHSRP40h3KJ7In8rAX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4EJPCzkbocEVajBVTovdna'},
#      'href': 'https://api.spotify.com/v1/albums/4EJPCzkbocEVajBVTovdna',
#      'id': '4EJPCzkbocEVajBVTovdna',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a6e0184629151bb89ee5144e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a6e0184629151bb89ee5144e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a6e0184629151bb89ee5144e',
#        'width': 64}],
#      'name': '9 Fitness And Cardio Hit List',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:4EJPCzkbocEVajBVTovdna'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4WcnnHSRP40h3KJ7In8rAX'},
#       'href': 'https://api.spotify.com/v1/artists/4WcnnHSRP40h3KJ7In8rAX',
#       'id': '4WcnnHSRP40h3KJ7In8rAX',
#       'name': 'Fitness Workout Hits',
#       'type': 'artist',
#       'uri': 'spotify:artist:4WcnnHSRP40h3KJ7In8rAX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 100022,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPW46224362'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1YVCNzqlBFIAkbhafuYGr8'},
#     'href': 'https://api.spotify.com/v1/tracks/1YVCNzqlBFIAkbhafuYGr8',
#     'id': '1YVCNzqlBFIAkbhafuYGr8',
#     'is_local': False,
#     'name': 'Push It Harder',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eaf03aad73d0d9b75114cc45474944bc0dc9ed47?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:1YVCNzqlBFIAkbhafuYGr8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VOK8y6IeYRgdss2xlvzc3'},
#        'href': 'https://api.spotify.com/v1/artists/6VOK8y6IeYRgdss2xlvzc3',
#        'id': '6VOK8y6IeYRgdss2xlvzc3',
#        'name': 'Gym Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6VOK8y6IeYRgdss2xlvzc3'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6wM9ROIZ5318oMevMjMlAg'},
#      'href': 'https://api.spotify.com/v1/albums/6wM9ROIZ5318oMevMjMlAg',
#      'id': '6wM9ROIZ5318oMevMjMlAg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736dda992b267d8b8b5191b071',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026dda992b267d8b8b5191b071',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516dda992b267d8b8b5191b071',
#        'width': 64}],
#      'name': '10 Bound To Dance',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6wM9ROIZ5318oMevMjMlAg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6VOK8y6IeYRgdss2xlvzc3'},
#       'href': 'https://api.spotify.com/v1/artists/6VOK8y6IeYRgdss2xlvzc3',
#       'id': '6VOK8y6IeYRgdss2xlvzc3',
#       'name': 'Gym Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6VOK8y6IeYRgdss2xlvzc3'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 106031,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPW46224370'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1bsjPFpBmtgCQAQG3hFlh3'},
#     'href': 'https://api.spotify.com/v1/tracks/1bsjPFpBmtgCQAQG3hFlh3',
#     'id': '1bsjPFpBmtgCQAQG3hFlh3',
#     'is_local': False,
#     'name': 'Drop Down',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a984420677df29e9710bcc26851135351e211016?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:1bsjPFpBmtgCQAQG3hFlh3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ihvWb92Gjq0KbRScprmFp'},
#      'href': 'https://api.spotify.com/v1/albums/2ihvWb92Gjq0KbRScprmFp',
#      'id': '2ihvWb92Gjq0KbRScprmFp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6fb546a02ff0f3fe760fc53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6fb546a02ff0f3fe760fc53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6fb546a02ff0f3fe760fc53',
#        'width': 64}],
#      'name': '31 Power Workouts',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:2ihvWb92Gjq0KbRScprmFp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 204927,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83868164'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1jNqnT3RMyW4zJgZLosE6N'},
#     'href': 'https://api.spotify.com/v1/tracks/1jNqnT3RMyW4zJgZLosE6N',
#     'id': '1jNqnT3RMyW4zJgZLosE6N',
#     'is_local': False,
#     'name': 'Fire',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c68b21c45a9d2964d8f64964733be92146d41f05?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1jNqnT3RMyW4zJgZLosE6N'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ihvWb92Gjq0KbRScprmFp'},
#      'href': 'https://api.spotify.com/v1/albums/2ihvWb92Gjq0KbRScprmFp',
#      'id': '2ihvWb92Gjq0KbRScprmFp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6fb546a02ff0f3fe760fc53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6fb546a02ff0f3fe760fc53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6fb546a02ff0f3fe760fc53',
#        'width': 64}],
#      'name': '31 Power Workouts',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:2ihvWb92Gjq0KbRScprmFp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 217142,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83868096'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1mTD1XA9fJpHGcqdxf1t89'},
#     'href': 'https://api.spotify.com/v1/tracks/1mTD1XA9fJpHGcqdxf1t89',
#     'id': '1mTD1XA9fJpHGcqdxf1t89',
#     'is_local': False,
#     'name': 'Mountain Peak',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c6a3d8f28a07ec1928a3650f32a35a3d4d39cedf?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 21,
#     'type': 'track',
#     'uri': 'spotify:track:1mTD1XA9fJpHGcqdxf1t89'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k5KeG8St6LiePh5blOwwl'},
#        'href': 'https://api.spotify.com/v1/artists/0k5KeG8St6LiePh5blOwwl',
#        'id': '0k5KeG8St6LiePh5blOwwl',
#        'name': 'Workout Music Tv',
#        'type': 'artist',
#        'uri': 'spotify:artist:0k5KeG8St6LiePh5blOwwl'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5YF9s2rxFyFl1xoSAujH9L'},
#      'href': 'https://api.spotify.com/v1/albums/5YF9s2rxFyFl1xoSAujH9L',
#      'id': '5YF9s2rxFyFl1xoSAujH9L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735e31ea3e479422fc1a288f22',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025e31ea3e479422fc1a288f22',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515e31ea3e479422fc1a288f22',
#        'width': 64}],
#      'name': '40 Happy Aerobic & Cardio Hits 2021 For Fitness & Workout (Unmixed Compilation for Fitness & Workout 128 Bpm / 32 Count)',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:5YF9s2rxFyFl1xoSAujH9L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0k5KeG8St6LiePh5blOwwl'},
#       'href': 'https://api.spotify.com/v1/artists/0k5KeG8St6LiePh5blOwwl',
#       'id': '0k5KeG8St6LiePh5blOwwl',
#       'name': 'Workout Music Tv',
#       'type': 'artist',
#       'uri': 'spotify:artist:0k5KeG8St6LiePh5blOwwl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 277604,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITC942017693'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1sGjF55ZKHMOCOAn29YBhE'},
#     'href': 'https://api.spotify.com/v1/tracks/1sGjF55ZKHMOCOAn29YBhE',
#     'id': '1sGjF55ZKHMOCOAn29YBhE',
#     'is_local': False,
#     'name': "This One's For You - Workout Remix 128 Bpm",
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca51c6c7c8434765b3dbb426e42a514ffbb3a145?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:1sGjF55ZKHMOCOAn29YBhE'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
# ...
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ihvWb92Gjq0KbRScprmFp'},
#      'href': 'https://api.spotify.com/v1/albums/2ihvWb92Gjq0KbRScprmFp',
#      'id': '2ihvWb92Gjq0KbRScprmFp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6fb546a02ff0f3fe760fc53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6fb546a02ff0f3fe760fc53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6fb546a02ff0f3fe760fc53',
#        'width': 64}],
#      'name': '31 Power Workouts',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:2ihvWb92Gjq0KbRScprmFp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 187034,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83867923'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3blY6KFMISO8Mq3Oj1wHhc'},
#     'href': 'https://api.spotify.com/v1/tracks/3blY6KFMISO8Mq3Oj1wHhc',
#     'id': '3blY6KFMISO8Mq3Oj1wHhc',
#     'is_local': False,
#     'name': 'The Pump',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/52f0e40179d718e738073767900f9ca6276fd6fd?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 30,
#     'type': 'track',
#     'uri': 'spotify:track:3blY6KFMISO8Mq3Oj1wHhc'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4n7nJMEY5cuQntfrmTiFh3'},
#      'href': 'https://api.spotify.com/v1/albums/4n7nJMEY5cuQntfrmTiFh3',
#      'id': '4n7nJMEY5cuQntfrmTiFh3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bd3e83acd53b6b80eb70c373',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bd3e83acd53b6b80eb70c373',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bd3e83acd53b6b80eb70c373',
#        'width': 64}],
#      'name': '31 Pumped Up Workouts',
#      'release_date': '2021-01-02',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:4n7nJMEY5cuQntfrmTiFh3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 195000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83864943'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3hAxLjJlTdGyN5XWBczjIT'},
#     'href': 'https://api.spotify.com/v1/tracks/3hAxLjJlTdGyN5XWBczjIT',
#     'id': '3hAxLjJlTdGyN5XWBczjIT',
#     'is_local': False,
#     'name': 'Burn',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/893e45c5fa996385bb71e89f8affcadbe5098bea?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 29,
#     'type': 'track',
#     'uri': 'spotify:track:3hAxLjJlTdGyN5XWBczjIT'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BzLbN9yomNn0cNE1sChPB'},
#        'href': 'https://api.spotify.com/v1/artists/4BzLbN9yomNn0cNE1sChPB',
#        'id': '4BzLbN9yomNn0cNE1sChPB',
#        'name': 'Workout Dance Factory',
#        'type': 'artist',
#        'uri': 'spotify:artist:4BzLbN9yomNn0cNE1sChPB'}],
#      'available_markets': ['AE',
#       'AU',
#       'BG',
#       'BH',
#       'BY',
#       'CY',
#       'EE',
#       'EG',
#       'FI',
#       'GR',
#       'HK',
#       'ID',
#       'IL',
#       'IN',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LT',
#       'LV',
#       'MD',
#       'MY',
#       'NZ',
#       'OM',
#       'PH',
#       'PS',
#       'QA',
#       'RO',
#       'RU',
#       'SA',
#       'SG',
#       'TH',
#       'TR',
#       'TW',
#       'UA',
#       'VN',
#       'ZA',
#       'AD',
#       'AL',
#       'AT',
#       'BA',
#       'BE',
#       'CH',
#       'CZ',
#       'DE',
#       'DK',
#       'DZ',
#       'ES',
#       'FR',
#       'HR',
#       'HU',
#       'IT',
#       'LI',
#       'LU',
#       'MA',
#       'MC',
#       'ME',
#       'MK',
#       'MT',
#       'NL',
#       'NO',
#       'PL',
#       'RS',
#       'SE',
#       'SI',
#       'SK',
#       'TN',
#       'XK',
#       'GB',
#       'IE',
#       'IS',
#       'PT',
#       'AR',
#       'BR',
#       'CL',
#       'PY',
#       'UY',
#       'BO',
#       'DO',
#       'CA',
#       'CO',
#       'EC',
#       'PA',
#       'PE',
#       'US',
#       'CR',
#       'GT',
#       'HN',
#       'MX',
#       'NI',
#       'SV'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6pbVTorbtUtW6tfzPCvlMs'},
#      'href': 'https://api.spotify.com/v1/albums/6pbVTorbtUtW6tfzPCvlMs',
#      'id': '6pbVTorbtUtW6tfzPCvlMs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f61f9c8d36d287f2bc26fe45',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f61f9c8d36d287f2bc26fe45',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f61f9c8d36d287f2bc26fe45',
#        'width': 64}],
#      'name': '21 Workouts',
#      'release_date': '2021-01-03',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6pbVTorbtUtW6tfzPCvlMs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4BzLbN9yomNn0cNE1sChPB'},
#       'href': 'https://api.spotify.com/v1/artists/4BzLbN9yomNn0cNE1sChPB',
#       'id': '4BzLbN9yomNn0cNE1sChPB',
#       'name': 'Workout Dance Factory',
#       'type': 'artist',
#       'uri': 'spotify:artist:4BzLbN9yomNn0cNE1sChPB'}],
#     'available_markets': ['AE',
#      'AU',
#      'BG',
#      'BH',
#      'BY',
#      'CY',
#      'EE',
#      'EG',
#      'FI',
#      'GR',
#      'HK',
#      'ID',
#      'IL',
#      'IN',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LT',
#      'LV',
#      'MD',
#      'MY',
#      'NZ',
#      'OM',
#      'PH',
#      'PS',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SG',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'VN',
#      'ZA',
#      'AD',
#      'AL',
#      'AT',
#      'BA',
#      'BE',
#      'CH',
#      'CZ',
#      'DE',
#      'DK',
#      'DZ',
#      'ES',
#      'FR',
#      'HR',
#      'HU',
#      'IT',
#      'LI',
#      'LU',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'NL',
#      'NO',
#      'PL',
#      'RS',
#      'SE',
#      'SI',
#      'SK',
#      'TN',
#      'XK',
#      'GB',
#      'IE',
#      'IS',
#      'PT',
#      'AR',
#      'BR',
#      'CL',
#      'PY',
#      'UY',
#      'BO',
#      'DO',
#      'CA',
#      'CO',
#      'EC',
#      'PA',
#      'PE',
#      'US',
#      'CR',
#      'GT',
#      'HN',
#      'MX',
#      'NI',
#      'SV'],
#     'disc_number': 1,
#     'duration_ms': 185714,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83867777'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/47OIw5dkrNDF9t038kcCjI'},
#     'href': 'https://api.spotify.com/v1/tracks/47OIw5dkrNDF9t038kcCjI',
#     'id': '47OIw5dkrNDF9t038kcCjI',
#     'is_local': False,
#     'name': 'Unknown',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cbdd6673c195b73764d41fcb7986c22b14b8d45f?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:47OIw5dkrNDF9t038kcCjI'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#        'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#        'id': '6kgJFG16FNotN7x1V4hwKI',
#        'name': 'Military Workout',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2ihvWb92Gjq0KbRScprmFp'},
#      'href': 'https://api.spotify.com/v1/albums/2ihvWb92Gjq0KbRScprmFp',
#      'id': '2ihvWb92Gjq0KbRScprmFp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6fb546a02ff0f3fe760fc53',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6fb546a02ff0f3fe760fc53',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6fb546a02ff0f3fe760fc53',
#        'width': 64}],
#      'name': '31 Power Workouts',
#      'release_date': '2021-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:2ihvWb92Gjq0KbRScprmFp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kgJFG16FNotN7x1V4hwKI'},
#       'href': 'https://api.spotify.com/v1/artists/6kgJFG16FNotN7x1V4hwKI',
#       'id': '6kgJFG16FNotN7x1V4hwKI',
#       'name': 'Military Workout',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kgJFG16FNotN7x1V4hwKI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 200275,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBPS83867951'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4aJu71rJqL8r9koSCLcm9Q'},
#     'href': 'https://api.spotify.com/v1/tracks/4aJu71rJqL8r9koSCLcm9Q',
#     'id': '4aJu71rJqL8r9koSCLcm9Q',
#     'is_local': False,
#     'name': 'Dreams',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/959e805f79862b8b647f222628bca2287f481d50?cid=60f45fe73bef4bfbb7549dde2b02cab5',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4aJu71rJqL8r9koSCLcm9Q'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=genre%3Aworkout+year%3A2021&type=track&offset=40&limit=20',
#   'offset': 20,
#   'previous': 'https://api.spotify.com/v1/search?query=genre%3Aworkout+year%3A2021&type=track&offset=0&limit=20',
#   'total': 352}}

# %% [markdown]
# ### 1.6 Wrap-Up
# ...
